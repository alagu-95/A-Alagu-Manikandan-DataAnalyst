# %% [markdown]
# #For Loop

# %% [markdown]
# Multiplication Table Generator

# %%
Tables = int(input("Enter a number (1 to 10) for multiplication table:"))
for i in range(1, 11):
  result = Tables * i
  print(f"{Tables} x {i} = {result}")
# Out:
# Enter a number (1 to 10) for multiplication table:5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %% [markdown]
# #Functions

# %% [markdown]
# BMI(Body Mass Index) Calculator

# %%
Weight = int(input("Enter your weight in Kg:"))

Height = float(input("Enter your height in m:"))

def calculate_bmi(Weight, Height):
  return Weight/(Height**2)

result = calculate_bmi(Weight, Height)
print(f"Your BMI is:{result:.2f} kg/m2")
# Out:
# Enter your weight in Kg:58
# Enter your height in m:1.62
# Your BMI is:22.10 kg/m2
