# %% [markdown]
# #List (Creation, Modification and Access)

# %% [markdown]
# 1. List Creation

# %%
Age_list = [96, 97, 98, 99, 100]
Age_list
# Out:
# [96, 97, 98, 99, 100]

# %%
Name_list = ['Ram', 'Laxman', 'Hanuman', 'Arjunan', 'Karnan']
Name_list
# Out:
# ['Ram', 'Laxman', 'Hanuman', 'Arjunan', 'Karnan']

# %% [markdown]
# 2. List Operations / Modifications

# %% [markdown]
# a.	Append the string "Yazhini" to name_list

# %%
Name_list.append("Yazhini")
Name_list
# Out:
# ['Ram', 'Laxman', 'Hanuman', 'Arjunan', 'Karnan', 'Yazhini']

# %% [markdown]
# b.	Insert the element 30 at index 2 in age_list

# %%
Age_list.insert(2, 30)
Age_list
# Out:
# [96, 97, 30, 98, 99, 100]

# %% [markdown]
# c.	Remove the string "Yazhini" from name_list

# %%
Name_list.remove("Yazhini")
Name_list
# Out:
# ['Ram', 'Laxman', 'Hanuman', 'Arjunan', 'Karnan']

# %% [markdown]
# d.	Pop the last element from age_list

# %%
Age_list.pop(-1)
Age_list
# Out:
# [96, 97, 30, 98, 99]

# %% [markdown]
# e.	Extend the age_list with additional ages [29, 30, 26]

# %%
Age_list.extend( [29, 30, 26])
Age_list
# Out:
# [96, 97, 30, 98, 99, 29, 30, 26]

# %% [markdown]
# f.	Sort age_list in descending order

# %%
Age_list.sort(reverse=True)
Age_list
# Out:
# [99, 98, 97, 96, 30, 30, 29, 26]

# %% [markdown]
# g.	Find Max age, Min age and sum of all ages from age_list

# %% [markdown]
# Max age

# %%
max(Age_list)
# Out:
# 99

# %% [markdown]
# Min age

# %%
min(Age_list)
# Out:
# 26

# %% [markdown]
# Sum of all ages

# %%
sum(Age_list)
# Out:
# 505

# %% [markdown]
# h.	Make a copy of age_list and store as age_list_copy

# %%
age_list_copy = Age_list.copy()
age_list_copy
# Out:
# [99, 98, 97, 96, 30, 30, 29, 26]

# %% [markdown]
# i.	Clear all elements from age_list_copy

# %%
age_list_copy.clear()
age_list_copy
# Out:
# []

# %% [markdown]
# 3. Accessing List Elements

# %% [markdown]
# a.	Print the first element of name_list

# %%
Name_list[0]
# Out:
# 'Ram'

# %% [markdown]
# b.	Print the last element of name_list

# %%
Name_list[-1]
# Out:
# 'Karnan'

# %% [markdown]
# c.	Print the elements from index 2 to index 4 in name_list

# %%
Name_list[2:]
# Out:
# ['Hanuman', 'Arjunan', 'Karnan']

# %% [markdown]
# d.	Print the elements of name_list in reverse order

# %%
Name_list.reverse()
Name_list
# Out:
# ['Karnan', 'Arjunan', 'Hanuman', 'Laxman', 'Ram']

# %% [markdown]
# e.	Create a list called list_dup = [1, 2, 1, 1, 3, 1, 2, 5, 9, 1] and print the number of times element ‘1’ has occurred

# %%
list_dup = [1, 2, 1, 1, 3, 1, 2, 5, 9, 1]
list_dup
# Out:
# [1, 2, 1, 1, 3, 1, 2, 5, 9, 1]

# %%
list_dup.count(1)
# Out:
# 5

# %% [markdown]
# f.	Print length of list_dup

# %%
len(list_dup)
# Out:
# 10

# %% [markdown]
# #Dictionary (Creation, Modification and Access)

# %% [markdown]
# 1. Dictionary Creation

# %% [markdown]
# a.	Create a dictionary named student_marks that maps the names of five students to their marks (use scale of from 0 to 100)

# %%
student_marks = {"Anil": 100, "Upendra": 99, "Dinesh": 98, "Singh": 97, "Kumar": 96}
student_marks
# Out:
# {'Anil': 100, 'Upendra': 99, 'Dinesh': 98, 'Singh': 97, 'Kumar': 96}

# %% [markdown]
# b.	Access and print the mark of a specific student, of your choice

# %%
student_marks["Upendra"]
# Out:
# 99

# %% [markdown]
# 2. Dictionary Modifications & Access

# %% [markdown]
# a.	Add a new student "Janani" with a mark of 80 to the student_marks dictionary

# %%
student_marks["Janani"] = 80
student_marks
# Out:
# {'Anil': 100,
#  'Upendra': 99,
#  'Dinesh': 98,
#  'Singh': 97,
#  'Kumar': 96,
#  'Janani': 80}

# %% [markdown]
# b.	Update the mark of any one older student to 82

# %%
student_marks.update({"Anil": 82})
student_marks
# Out:
# {'Anil': 82,
#  'Upendra': 99,
#  'Dinesh': 98,
#  'Singh': 97,
#  'Kumar': 96,
#  'Janani': 80}

# %% [markdown]
# c.	Use the keys(), values(), and items() methods to print all keys, values, and key-value pairs in the student_marks dictionary

# %% [markdown]
# Keys

# %%
student_marks.keys()
# Out:
# dict_keys(['Anil', 'Upendra', 'Dinesh', 'Singh', 'Kumar', 'Janani'])

# %% [markdown]
# Values

# %%
student_marks.values()
# Out:
# dict_values([82, 99, 98, 97, 96, 80])

# %% [markdown]
# Items

# %%
student_marks.items()
# Out:
# dict_items([('Anil', 82), ('Upendra', 99), ('Dinesh', 98), ('Singh', 97), ('Kumar', 96), ('Janani', 80)])

# %% [markdown]
# #Sets & Frozensets

# %% [markdown]
# 1. Sets

# %% [markdown]
# a.	Create a set called my_set with following values:
# 	['a','e','i','o','u','a','a','i']
# Analyse the output and provide explanation for the same

# %%
my_set = ['a','e','i','o','u','a','a','i']
my_set
# Out:
# ['a', 'e', 'i', 'o', 'u', 'a', 'a', 'i']

# %%
my_set_id = set(my_set)
my_set_id
# Out:
# {'a', 'e', 'i', 'o', 'u'}

# %% [markdown]
# b.	Attempt to change the value of my_set[4] = 's'. If code throws an error, provide an explanation

# %%
my_set[4] = 's'
my_set
# Out:
# ['a', 'e', 'i', 'o', 's', 'a', 'a', 'i']

# %% [markdown]
# c.	Create two sets

# %%
set1 = {1, 3, 5, 7, 9}
set1
# Out:
# {1, 3, 5, 7, 9}

# %%
set2 = {2, 3, 5, 8, 10}
set2
# Out:
# {2, 3, 5, 8, 10}

# %% [markdown]
# d.	Compute the union of set1 and set2, and print the result

# %%
union = set1 | set2
union
# Out:
# {1, 2, 3, 5, 7, 8, 9, 10}

# %% [markdown]
# e.	Perform an intersection operation between set1 and set2, and print the result

# %%
intersection = set1 & set2
intersection
# Out:
# {3, 5}

# %% [markdown]
# 2. Frozensets

# %% [markdown]
# a.	Create a frozenset named immutable_set containing the integers: 1, 2, 3, 4, 5. Print the frozenset

# %%
immutable_set = [1, 2, 3, 4, 5]
immutable_set
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers = frozenset(immutable_set)
numbers
# Out:
# frozenset({1, 2, 3, 4, 5})

# %% [markdown]
# b.	Try to add an element (e.g., 6) to the immutable_set frozenset. Observe and describe any exceptions that occur.

# %%
numbers.add(6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-b8cd573708b1> in <cell line: 0>()
# ----> 1 numbers.add(6)
#
# AttributeError: 'frozenset' object has no attribute 'add'
